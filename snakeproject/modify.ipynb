# %%
import numpy as np 
from synth_pat.paths import Paths

file = f'{Paths.RESULTS}/jdopa_ws_sweep.npz'

loaded = np.load(file)

bold = loaded['bold']
raw = loaded['raw']

params = loaded['params']
params = params.T


np.savez(f'{Paths.RESULTS}/2jdopa_ws_sweep.npz', bold=bold, raw=raw, params=params)

# %%
import numpy as np 
from synth_pat.paths import Paths

file = f'{Paths.RESULTS}/jdopa_ws_sweep.npz'

loaded = np.load(file)

#bold = loaded['bold']
#raw = loaded['raw']

params = loaded['params']
#params = params.T

# %%
params
# Out:
# array([[1.00e+02, 3.20e-02, 3.00e-03],
#        [3.00e-03, 3.20e-02, 1.00e+01],
#        [1.00e+00, 1.00e-03, 3.20e-02],
#        ...,
#        [1.00e+02, 3.20e-02, 3.20e-02],
#        [1.00e-03, 1.00e-01, 3.16e-01],
#        [1.00e-02, 3.00e-03, 3.20e-02]])
